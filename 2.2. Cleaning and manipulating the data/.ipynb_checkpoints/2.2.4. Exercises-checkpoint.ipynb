# %% [markdown]
# ### Exercises
# #### Removing duplicates
# Import the following dataset:

# %%
import pandas as pd

df = pd.read_csv("http://bit.ly/chiporders", sep="\t")

# %% [markdown]
# Perform the following steps:
#
# * Find the number of duplicated rows.
# * Find the number of duplicated values in each column.
# * Find the number of duplicated rows with respect to the columns 'order_id', 'item_name' and 'item_price'.
# * Remove all occurrences of the duplicated rows with respect to the columns 'order_id', 'item_name' and 'item_price'.

# %% [markdown]
# #### Solution
# Find the number of duplicated rows.

# %%
df.duplicated().sum()
# Out:
# 59

# %% [markdown]
# Find the number of duplicated values in each column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
column_names=df.columns
for x in column_names:
    print(str(df.duplicated([x]).sum())+str(" in column ")+ x)
# Out:
# 2788 in column order_id
# 4613 in column quantity
# 4572 in column item_name
# 3578 in column choice_description
# 4544 in column item_price

# %% [markdown]
# Find the number of duplicated rows with respect to the columns 'order_id', 'item_name' and 'item_price'.

# %%
# In these three columns all of the entries that are the same if True (already appeared in previous values)
df.duplicated(['order_id', 'item_name', 'item_price']).sum()
# Out:
# 249

# %% [markdown]
# Remove all occurrences of the duplicated rows with respect to the columns 'order_id', 'item_name' and 'item_price'.

# %%
df.drop_duplicates(['order_id', 'item_name', 'item_price'], keep=False) #with keep=False we maintain only the arguments that are false to duplication
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4613      1831         1                                  Chips
# 4614      1831         1                          Bottled Water
# 4615      1832         1                     Chicken Soft Tacos
# 4616      1832         1                    Chips and Guacamole
# 4619      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# #### Multiple filtering
#
# In this unit, you will practice filtering the rows of a DataFrame by multiple conditions. You will use a dataset that we already looked at in a previous unit: the TMDB 5000 Movie Dataset. If you need to download the csv file again, you can find it under the Resources tab.
#
# Complete the following tasks.
#
# * Import the dataset as a pandas DataFrame.
# * Find the names of all the movies whose length is at least 180min.
# * Using multiple filtering, find the names of all the movies whose length is at least 180min, or whose vote average is at least 8.0. (Hint: use the logical operator | )
# * Using multiple filtering find the names of all the movies whose length is at least 180min, and whose vote average is at least 8.0. (Hint: use the logical operator & )
# * Using multiple filtering, find the names of all the movies whose length is at least 180min, and whose vote average is at least 8.0 and whose original language is not English. (Hint: use the logical operator & twice )
# * Hint: You will have to use the bitwise logical operators |(or) and &(and):

# %% [markdown]
# Import the dataset as a pandas DataFrame.

# %%
import pandas as pd

df = pd.read_csv("c2_tmdb_5000_movies.csv")

# %% [markdown]
# Find the names of all the movies whose length is at least 180min.

# %%
df.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
# ...

# %%
df[df.runtime>=180].title
# Out:
# 24                                          King Kong
# 25                                            Titanic
# 110                                      Pearl Harbor
# 298                           The Wolf of Wall Street
# 329     The Lord of the Rings: The Return of the King
# 676                                        Wyatt Earp
# 690                                    The Green Mile
# 855                                 Gods and Generals
# 880                                        Grindhouse
# 1091                                            Nixon
# 1109                                    Heaven's Gate
# 1125                                        Cleopatra
# 1181                                              JFK
# 1333                                         Magnolia
# 1387                                        Malcolm X
# 1456                                   Bound by Honor
# 1477                                             Reds
# ...

# %% [markdown]
# Using multiple filtering, find the names of all the movies whose length is at least 180min, or whose vote average is at least 8.0. (Hint: use the logical operator | )

# %%
df[(df.runtime>=180)|(df.vote_average>8)].title
# Out:
# 24            King Kong
# 25              Titanic
# 65      The Dark Knight
# 95         Interstellar
# 96            Inception
#              ...
# 4535      Seven Samurai
# 4592        Intolerance
# 4602       12 Angry Men
# 4662     Little Big Top
# 4755           Counting
# Name: title, Length: 90, dtype: object

# %% [markdown]
# Using multiple filtering find the names of all the movies whose length is at least 180min, and whose vote average is at least 8.0. (Hint: use the logical operator & )

# %%
df[(df.runtime>=180)&(df.vote_average>8)].title
# Out:
# 329     The Lord of the Rings: The Return of the King
# 690                                    The Green Mile
# 1663                      Once Upon a Time in America
# 1818                                 Schindler's List
# 2731                           The Godfather: Part II
# 3723                             Anne of Green Gables
# 4535                                    Seven Samurai
# Name: title, dtype: object

# %% [markdown]
# Using multiple filtering, find the names of all the movies whose length is at least 180min, and whose vote average is at least 8.0 and whose original language is not English. (Hint: use the logical operator & twice )

# %%
df[(df.runtime>=180)&(df.vote_average>8)&(df.original_language!="en")].title
# Out:
# 4535    Seven Samurai
# Name: title, dtype: object

# %% [markdown]
# #### Exercise: applying functions
# Perform the following tasks.
#
# 1) Create a new column called Manufacturer which takes the entries in the column mfr and maps them to the full name as follows:
#
# - A = American Home Food Products;
# - G = General Mills
# - K = Kelloggs
# - N = Nabisco
# - P = Post
# - Q = Quaker Oats
# - R = Ralston Purina
#
# 2) Calories can be converted to kilojoules using the following formula: 1 calorie = 4.184 kilojoules. Find the amount of Kilojoules per serving for each cereal. Store the results in a new column.
#
# 3) For each numerical column, find the cereal with the maximum value per column.

# %%
# Import libraries
import pandas as pd
import numpy as np

# Load data
df = pd.read_csv("c2_cereal.csv")

# Print data shape
print('Data shape: ',df.shape)
# Out:
# Data shape:  (77, 16)

# %%
df["Manufacturer"] = df.mfr.map({"A": "American Home Food Products", "G": "General Mills", "K": "Kelloggs", "N": "Nabisco", "P": "Post", "Q": "Quaker Oats", "G": "Ralston Purina"})
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
def kj(x):
    y = x*4.184
    return(y)

df["KJ"]=df.calories.apply(kj)
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
df.columns.to_list()
df_num = df.loc[:, ['calories','protein','fat','sodium','fiber','carbo','sugars','potass','vitamins','shelf','weight','cups','rating', 'KJ']]
df_num.apply(max, axis=0)
# Out:
# calories    160.000000
# protein       6.000000
# fat           5.000000
# sodium      320.000000
# fiber        14.000000
# carbo        23.000000
# sugars       15.000000
# potass      330.000000
# vitamins    100.000000
# shelf         3.000000
# weight        1.500000
# cups          1.500000
# rating       93.704912
# KJ          669.440000
# dtype: float64
