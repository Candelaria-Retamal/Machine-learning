# %% [markdown]
# The goal of this exercise is to experiment with the different classifiers that we saw so far
#
# * Logistic regression
# * k-NN
# * Decision trees
# * Random forests
# * SVM with linear and RBF kernels
#
# Again, we will work on a dataset with only two features such that you can visualize your classifiers by plotting their decision surfaces. We provide a decision_surface() function below to do that. For each classifier from above, play with the different parameters (max_depth, n_estimators, C, gamma, and so on) and visualize their effect on the decision surface.

# %%
from IPython.display import Image
Image(filename="spiral.png")
